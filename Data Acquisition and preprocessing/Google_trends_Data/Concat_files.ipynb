# %%
# keyword, df name
keywords = [['Microsoft','Microsoft'],
['Apple','Apple'],
['Amazon','Amazon'],
['Google','Google'],
['Facebook','Facebook'],
['Johnson & Johnson','Johnson_and_Johnson'],
['Walmart','Walmart'],
['Procter & Gamble','Procter_and_Gamble'],
['JPMorgan Chase','JPMorgan_Chase'],
['UnitedHealth Group','UnitedHealth_Group'],
['Intel','Intel'],
['Verizon','Verizon'],
['AT&T','AT_T'],
['The Home Depot','The_Home_Depot'],
['Merck','Merck'],
['Pfizer','Pfizer'],
['CocaCola','CocaCola'],
['Bank of America','Bank_of_America'],
['Netflix','Netflix'],
['Pepsi','Pepsi'],
['Disney','The_Walt_Disney'],
['Cisco','Cisco_Systems'],
['NVIDIA','NVIDIA'],
['Exxon','Exxon_Mobil'],
['Abbott Laboratories','Abbott_Laboratories'],
['Oracle','Oracle'],
['Comcast','Comcast'],
['Adobe','Adobe'],
['Chevron','Chevron'],
['Eli Lilly','Eli_Lilly'],
['Covid 19','Covid_19'],
['Pandemic','Pandemic'],
['presidential election','presidential_election'], 
['Lockdown','Lockdown'],
['Face masks','Face_masks'],
['Coronavirus','Coronavirus'], 
['Quarantine','Quarantine'],           
['EDD','EDD'],                     
['sba loans','sba_loans']]

# %%
len(keywords)
# Out:
# 39

# %%
import pandas as pd
import csv

# %%
for key,df_name in keywords:
    globals()[df_name] = pd.read_csv(df_name + ".csv",index_col=0)

# %%
files_name_lists = []
for key,df_name in keywords:
    files_name_lists.append(df_name)

print(files_name_lists)
# Out:
# ['Microsoft', 'Apple', 'Amazon', 'Google', 'Facebook', 'Johnson_and_Johnson', 'Walmart', 'Procter_and_Gamble', 'JPMorgan_Chase', 'UnitedHealth_Group', 'Intel', 'Verizon', 'AT_T', 'The_Home_Depot', 'Merck', 'Pfizer', 'CocaCola', 'Bank_of_America', 'Netflix', 'Pepsi', 'The_Walt_Disney', 'Cisco_Systems', 'NVIDIA', 'Exxon_Mobil', 'Abbott_Laboratories', 'Oracle', 'Comcast', 'Adobe', 'Chevron', 'Eli_Lilly', 'Covid_19', 'Pandemic', 'presidential_election', 'Lockdown', 'Face_masks', 'Coronavirus', 'Quarantine', 'EDD', 'sba_loans']

# %%
translation = {39: None} 
files_name = str(files_name_lists).translate(translation)
print(files_name)
# Out:
# [Microsoft, Apple, Amazon, Google, Facebook, Johnson_and_Johnson, Walmart, Procter_and_Gamble, JPMorgan_Chase, UnitedHealth_Group, Intel, Verizon, AT_T, The_Home_Depot, Merck, Pfizer, CocaCola, Bank_of_America, Netflix, Pepsi, The_Walt_Disney, Cisco_Systems, NVIDIA, Exxon_Mobil, Abbott_Laboratories, Oracle, Comcast, Adobe, Chevron, Eli_Lilly, Covid_19, Pandemic, presidential_election, Lockdown, Face_masks, Coronavirus, Quarantine, EDD, sba_loans]

# %%
df = pd.concat([Microsoft, Apple, Amazon, Google, Facebook, Johnson_and_Johnson, Walmart, Procter_and_Gamble, JPMorgan_Chase, UnitedHealth_Group, Intel, Verizon, AT_T, The_Home_Depot, Merck, Pfizer, CocaCola, Bank_of_America, Netflix, Pepsi, The_Walt_Disney, Cisco_Systems, NVIDIA, Exxon_Mobil, Abbott_Laboratories, Oracle, Comcast, Adobe, Chevron, Eli_Lilly, Covid_19, Pandemic, presidential_election, Lockdown, Face_masks, Coronavirus, Quarantine, EDD, sba_loans],axis=1)

# %%
df
# Out:
#             Microsoft  Apple  Amazon  Google  Facebook  Johnson & Johnson  \
# 2011-01-01      61.00  31.02   30.94   39.56     85.00              28.47
# 2011-01-02      72.00  32.01   34.00   38.18     74.80              15.33
# 2011-01-03      88.00  29.04   30.26   39.10     63.75              53.29
# 2011-01-04      95.00  28.71   29.58   41.40     63.75              46.72
# 2011-01-05      98.00  27.39   28.56   41.40     60.35              58.40
# ...               ...    ...     ...     ...       ...                ...
# 2020-04-26      38.25  41.80   92.15   26.73     28.48              21.45
# 2020-04-27      65.25  37.84   89.24   76.95     24.96              27.30
# 2020-04-28      66.00    NaN   86.33   81.00     25.28              22.62
# 2020-04-29      70.50    NaN   90.21   80.19     25.92              23.01
# 2020-04-30        NaN    NaN   93.12     NaN       NaN                NaN
#
#             Walmart  Procter & Gamble  JPMorgan Chase  UnitedHealth Group  \
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.rcParams["figure.figsize"] = (15,10)
plt.rcParams['axes.grid'] = True 
Walmart.plot()

# %%
df.to_csv("Google_trends_data.csv", encoding = "utf-8")

# %%
df
# Out:
#             Microsoft  Apple  Amazon  Google  Facebook  Johnson & Johnson  \
# 2011-01-01      61.00  31.02   30.94   39.56     85.00              28.47
# 2011-01-02      72.00  32.01   34.00   38.18     74.80              15.33
# 2011-01-03      88.00  29.04   30.26   39.10     63.75              53.29
# 2011-01-04      95.00  28.71   29.58   41.40     63.75              46.72
# 2011-01-05      98.00  27.39   28.56   41.40     60.35              58.40
# ...               ...    ...     ...     ...       ...                ...
# 2020-04-26      38.25  41.80   92.15   26.73     28.48              21.45
# 2020-04-27      65.25  37.84   89.24   76.95     24.96              27.30
# 2020-04-28      66.00    NaN   86.33   81.00     25.28              22.62
# 2020-04-29      70.50    NaN   90.21   80.19     25.92              23.01
# 2020-04-30        NaN    NaN   93.12     NaN       NaN                NaN
#
#             Walmart  Procter & Gamble  JPMorgan Chase  UnitedHealth Group  \
# ...

# %%
df1 = pd.concat([Amazon, Procter_and_Gamble, JPMorgan_Chase, UnitedHealth_Group, Intel, Verizon, AT_T, The_Home_Depot, Merck, Pfizer, CocaCola, Bank_of_America, Netflix, Pepsi, The_Walt_Disney, Cisco_Systems, NVIDIA, Exxon_Mobil, Abbott_Laboratories, Oracle, Comcast, Adobe, Chevron],axis=1)

# %%
df1
# Out:
#             Amazon  Procter & Gamble  JPMorgan Chase  UnitedHealth Group  \
# 2011-01-01   30.94             26.88           33.44               22.77
# 2011-01-02   34.00             32.64           27.36               57.27
# 2011-01-03   30.26             17.28           53.96               44.16
# 2011-01-04   29.58             33.28           52.44               14.49
# 2011-01-05   28.56              0.00           34.20               49.68
# ...            ...               ...             ...                 ...
# 2020-04-26   92.15             24.96           16.20               13.02
# 2020-04-27   89.24             52.48           29.70               31.00
# 2020-04-28   86.33             39.04           28.62               55.80
# 2020-04-29   90.21             21.76           32.40               58.28
# 2020-04-30   93.12             25.60           40.50               21.70
#
#             Intel  Verizon   AT&T  The Home Depot  Merck  Pfizer  ...  Pepsi  \
# ...

# %%
df1 = pd.concat([Amazon, Procter_and_Gamble, JPMorgan_Chase, UnitedHealth_Group, Verizon, AT_T, Oracle, Comcast, Adobe],axis=1)

# %%
df1
# Out:
#             Amazon  Procter & Gamble  JPMorgan Chase  UnitedHealth Group  \
# date
# 2011-01-01   30.94             26.88           33.44               22.77
# 2011-01-02   34.00             32.64           27.36               57.27
# 2011-01-03   30.26             17.28           53.96               44.16
# 2011-01-04   29.58             33.28           52.44               14.49
# 2011-01-05   28.56              0.00           34.20               49.68
# ...            ...               ...             ...                 ...
# 2020-04-26   92.15             24.96           16.20               13.02
# 2020-04-27   89.24             52.48           29.70               31.00
# 2020-04-28   86.33             39.04           28.62               55.80
# 2020-04-29   90.21             21.76           32.40               58.28
# 2020-04-30   93.12             25.60           40.50               21.70
#
#             Verizon   AT&T  Oracle  Comcast  Adobe
# date
# ...
